# %%
import numpy as np
import pandas as pd

# %%
x=[2,3,4]
y=[5,6,7]
# avariable that calculates the correlation btn x and y

# %%
x_array = np.array(x)
y_array =np.array(y) 
print(x_array, y_array)
# Out:
# [2 3 4] [5 6 7]

# %%
corr= np.corrcoef(x_array, y_array)
corr
# Out:
# array([[1., 1.],
#        [1., 1.]])

# %%
df= pd.read_csv(r'C:\Users\Administrator\Documents\train_data_cross-sell.csv', encoding="latin1")
df.head()
# Out:
#          ÿid  Gender       Customer_Date_of_Birth  Driving_License  \
# 0  549771831    Male        Monday, March 7, 1977                1
# 1  373583351    Male    Sunday, December 29, 2002                1
# 2  933163655  Female     Tuesday, August 23, 1994                1
# 3  698942186  Female  Thursday, November 18, 1999                1
# 4  515109822    Male  Thursday, February 22, 2001                1
#
#   Customer_Residence_Sub_County  Previously_Insured  \
# 0                      EMBAKASI                   0
# 1                     WESTLANDS                   1
# 2                     DAGORETTI                   1
# 3                          JUJA                   0
# 4                     WESTLANDS                   0
#
#    Vehicle_Year_of_Manufacture Vehicle_Damage  Annual_Premium      Agent_name  \
# 0                         2020            Yes           38294   Jomo Kenyatta
# 1                         2020             No           28619  Obiero Ochieng
# ...

# %%
df.columns
# Out:
# Index(['ÿid', 'Gender', 'Customer_Date_of_Birth', 'Driving_License',
#        'Customer_Residence_Sub_County', 'Previously_Insured',
#        'Vehicle_Year_of_Manufacture', 'Vehicle_Damage', 'Annual_Premium',
#        'Agent_name', 'Life_policy_start_date', 'Response'],
#       dtype='object')

# %%
import sklearn.preprocessing
import datetime

# %%
# Out:
#         Gender       Customer_Date_of_Birth  Driving_License  \
# 0         Male        Monday, March 7, 1977                1
# 1         Male    Sunday, December 29, 2002                1
# 2       Female     Tuesday, August 23, 1994                1
# 3       Female  Thursday, November 18, 1999                1
# 4         Male  Thursday, February 22, 2001                1
# ...        ...                          ...              ...
# 324461    Male       Friday, April 29, 1977                1
# 324462    Male    Tuesday, November 8, 1949                1
# 324463    Male      Saturday, April 2, 1994                1
# 324464    Male    Monday, December 23, 2002                1
# 324465  Female    Monday, November 21, 1955                1
#
#         Previously_Insured  Vehicle_Year_of_Manufacture Vehicle_Damage  \
# 0                        0                         2020            Yes
# 1                        1                         2020             No
# ...

# %%
from datetime import datetime
cd = datetime.now().year
print(cd)
# Out:
# 2025

# %%
df=df['Customer_Date_of_Birth']=pd.to_datetime(df ['Customer_Date_of_Birth'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df=df['Customer_Date_of_Birth']=pd.to_datetime(df ['Customer_Date_of_Birth'])
#
# NameError: name 'pd' is not defined

# %%
df['age']=cd-df['Customer_Date_of_Birth'].dt.year

# %%
df.head()
# Out:
#          ÿid  Gender Customer_Date_of_Birth  Driving_License  \
# 0  549771831    Male             1977-03-07                1
# 1  373583351    Male             2002-12-29                1
# 2  933163655  Female             1994-08-23                1
# 3  698942186  Female             1999-11-18                1
# 4  515109822    Male             2001-02-22                1
#
#   Customer_Residence_Sub_County  Previously_Insured  \
# 0                      EMBAKASI                   0
# 1                     WESTLANDS                   1
# 2                     DAGORETTI                   1
# 3                          JUJA                   0
# 4                     WESTLANDS                   0
#
#    Vehicle_Year_of_Manufacture Vehicle_Damage  Annual_Premium      Agent_name  \
# 0                         2020            Yes           38294   Jomo Kenyatta
# 1                         2020             No           28619  Obiero Ochieng
# ...

# %%
####df['Tenurein months'] = datetime.now()-pd.to_datetime(df['Life_policy_start_date']))//np.timedelta64(1,'m')

# %%
from sklearn.preprocessing import LabelEncoder
unique_counts =df.nunique()
columns_to_encode = unique_counts[unique_counts <=2].index.tolist()
le=LabelEncoder()
for col in columns_to_encode:
    df[col]= le.fit_transform(df[col])

df.head()
# Out:
#          ÿid  Gender Customer_Date_of_Birth  Driving_License  \
# 0  549771831       1             1977-03-07                1
# 1  373583351       1             2002-12-29                1
# 2  933163655       0             1994-08-23                1
# 3  698942186       0             1999-11-18                1
# 4  515109822       1             2001-02-22                1
#
#   Customer_Residence_Sub_County  Previously_Insured  \
# 0                      EMBAKASI                   0
# 1                     WESTLANDS                   1
# 2                     DAGORETTI                   1
# 3                          JUJA                   0
# 4                     WESTLANDS                   0
#
#    Vehicle_Year_of_Manufacture  Vehicle_Damage  Annual_Premium  \
# 0                         2020               1           38294
# 1                         2020               0           28619
# 2                         2011               0           27496
# ...

# %%
#droping a column
df= df.drop(columns=["Customer_Residence_Sub_County", "Agent_name", "ÿid"],axis=1)
df
# Out:
#         Gender Customer_Date_of_Birth  Driving_License  Previously_Insured  \
# 0            1             1977-03-07                1                   0
# 1            1             2002-12-29                1                   1
# 2            0             1994-08-23                1                   1
# 3            0             1999-11-18                1                   0
# 4            1             2001-02-22                1                   0
# ...        ...                    ...              ...                 ...
# 324461       1             1977-04-29                1                   0
# 324462       1             1949-11-08                1                   1
# 324463       1             1994-04-02                1                   1
# 324464       1             2002-12-23                1                   1
# 324465       0             1955-11-21                1                   0
#
# ...

# %%
df.columns
# Out:
# Index(['Gender', 'Customer_Date_of_Birth', 'Driving_License',
#        'Previously_Insured', 'Vehicle_Year_of_Manufacture', 'Vehicle_Damage',
#        'Annual_Premium', 'Life_policy_start_date', 'Response', 'age'],
#       dtype='object')

# %%
#droping a column
df=df.drop(columns=["Customer_Date_of_Birth", "Life_policy_start_date"],axis=1)

# %%
y= df['Response']
x=df.drop(['Response'], axis=1)
x.head()
# Out:
#    Gender  Driving_License  Previously_Insured  Vehicle_Year_of_Manufacture  \
# 0       1                1                   0                         2020
# 1       1                1                   1                         2020
# 2       0                1                   1                         2011
# 3       0                1                   0                         2020
# 4       1                1                   0                         2015
#
#    Vehicle_Damage  Annual_Premium  age
# 0               1           38294   48
# 1               0           28619   23
# 2               0           27496   31
# 3               1            2630   26
# 4               1           23367   24

# %%
correlation = x.corr()
print(correlation)
# Out:
#                                Gender  Driving_License  Previously_Insured  \
# Gender                       1.000000        -0.017559           -0.080665
# Driving_License             -0.017559         1.000000            0.014507
# Previously_Insured          -0.080665         0.014507            1.000000
# Vehicle_Year_of_Manufacture  0.002036         0.000916            0.002715
# Vehicle_Damage               0.090602        -0.016720           -0.824459
# Annual_Premium               0.003636        -0.012270            0.004200
# age                          0.144806        -0.078815           -0.254317
#
#                              Vehicle_Year_of_Manufacture  Vehicle_Damage  \
# Gender                                          0.002036        0.090602
# Driving_License                                 0.000916       -0.016720
# Previously_Insured                              0.002715       -0.824459
# Vehicle_Year_of_Manufacture                     1.000000       -0.000956
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.Figure(figsize=(8,5))
sns.heatmap(correlation, annot=True, cmap="viridis")
#annot =true shows values and cmap basically is color
plt.title('correlation heatmap')
plt.show()
